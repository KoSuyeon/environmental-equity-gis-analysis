# %%
import pandas as pd
df = pd.read_csv('data/동별데이터.csv',encoding='cp949').drop('도시재생사업수',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425 entries, 0 to 424
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   시군구         425 non-null    object
#  1   행정동         425 non-null    object
#  2   기초수급자_인구밀도  425 non-null    float64
#  3   저소득층_비율     425 non-null    float64
#  4   총생활인구       425 non-null    float64
#  5   초미세먼지       425 non-null    float64
#  6   미세먼지        425 non-null    float64
#  7   인당녹지면적      425 non-null    float64
#  8   토지공시지가평균    425 non-null    float64
#  9   임야공시지가평균    425 non-null    float64
#  10  총공시지가평균     425 non-null    float64
#  11  평균기온(°C)    425 non-null    float64
# dtypes: float64(10), object(2)
# memory usage: 40.0+ KB

# %%
df_시군구 = df[df.시군구.isin(['강북구','강서구','관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '양천구','은평구', '중랑구'])].reset_index(drop=True)

# %%
df_시군구
# Out:
#      시군구   행정동   기초수급자_인구밀도   저소득층_비율        총생활인구  초미세먼지  미세먼지     인당녹지면적  \
# 0    강북구   미아동  1376.344086  0.002521  46126.52190   19.0  39.0   2.966859
# 1    강북구   번1동  1853.030303  0.002245  34978.28285   19.0  39.0  24.744599
# 2    강북구   번2동  1985.263158  0.001812  24767.35190   19.0  39.0  26.506212
# 3    강북구   번3동  2597.272727  0.002059  28020.96143   19.0  39.0  22.599169
# 4    강북구  삼각산동  2127.419355  0.003256  42185.30286   19.0  39.0   1.465121
# ..   ...   ...          ...       ...          ...    ...   ...        ...
# 187  중랑구  상봉2동  1696.923077  0.002225  50746.33619   19.0  38.0   0.379986
# 188  중랑구  신내1동   819.140625  0.003548  67261.26096   19.0  38.0   5.115462
# 189  중랑구  신내2동  1548.387097  0.002477  33428.43667   19.0  38.0   4.674190
# 190  중랑구  중화1동  1726.562500  0.001946  33644.23619   19.0  38.0   0.798709
# 191  중랑구  중화2동  2486.138614  0.003055  47698.16952   19.0  38.0   1.509248
#
#          토지공시지가평균       임야공시지가평균       총공시지가평균  평균기온(°C)
# ...

# %%
df_시군구.to_csv('data/최종_데이터/최종_1차군집결과.csv',encoding='cp949',index=False)
