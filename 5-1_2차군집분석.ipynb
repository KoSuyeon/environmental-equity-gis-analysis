# %%
import pandas as pd
df = pd.read_csv('최종_분석데이터.csv',encoding='cp949')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75004 entries, 0 to 75003
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   grid        75004 non-null  int64
#  1   시도          75004 non-null  object
#  2   시군구         75004 non-null  object
#  3   행정동         75004 non-null  object
#  4   행정동코드       75004 non-null  int64
#  5   법정동코드       75004 non-null  int64
#  6   법정동         75004 non-null  object
#  7   대중교통        75004 non-null  float64
#  8   도시재생사업수     75004 non-null  int64
#  9   기초수급자_인구밀도  75004 non-null  float64
#  10  저소득층_비율     75004 non-null  float64
#  11  총생활인구       75004 non-null  float64
#  12  초미세먼지       75004 non-null  int64
#  13  미세먼지        75004 non-null  int64
#  14  인당녹지면적      73991 non-null  float64
#  15  토지공시지가평균    75004 non-null  float64
#  16  임야공시지가평균    75004 non-null  float64
#  17  총공시지가평균     75004 non-null  float64
#  18  토지유형        75004 non-null  object
# ...

# %%
df_행정동 = df[df.행정동.isin(['공릉1동','방이2동', '상계6·7동', '석촌동', '송중동', '송파1동', '잠실본동', '조원동', '청룡동', '화곡8동'])].iloc[:,:-3].reset_index(drop=True)

# %%
df_행정동.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1254 entries, 0 to 1253
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   grid        1254 non-null   int64
#  1   시도          1254 non-null   object
#  2   시군구         1254 non-null   object
#  3   행정동         1254 non-null   object
#  4   행정동코드       1254 non-null   int64
#  5   법정동코드       1254 non-null   int64
#  6   법정동         1254 non-null   object
#  7   대중교통        1254 non-null   float64
#  8   도시재생사업수     1254 non-null   int64
#  9   기초수급자_인구밀도  1254 non-null   float64
#  10  저소득층_비율     1254 non-null   float64
#  11  총생활인구       1254 non-null   float64
#  12  초미세먼지       1254 non-null   int64
#  13  미세먼지        1254 non-null   int64
#  14  인당녹지면적      1254 non-null   float64
#  15  토지공시지가평균    1254 non-null   float64
#  16  임야공시지가평균    1254 non-null   float64
# dtypes: float64(7), int64(6), object(4)
# memory usage: 166.7+ KB

# %%
df_행정동.to_csv('최종데이터_2차군집결과.csv',encoding='cp949',index=False)

# %%
df_행정동.행정동.unique()
# Out:
# array(['송중동', '상계6·7동', '공릉1동', '화곡8동', '조원동', '청룡동', '방이2동', '송파1동',
#        '석촌동', '잠실본동'], dtype=object)

# %%
 '공릉1동' '방이2동', '상계6·7동', '석촌동', '송중동', '송파1동', '잠실본동', '조원동', '청룡동', '화곡8동'
